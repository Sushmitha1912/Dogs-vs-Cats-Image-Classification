# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
DATASET_PATH = r"C:\Users\kappa\Downloads\kagglecatsanddogs_5340\PetImages"

# %%
IMG_SIZE = (160, 160)
BATCH_SIZE = 32

train_dataset = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
).ignore_errors()

val_dataset = tf.keras.utils.image_dataset_from_directory(
    DATASET_PATH,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
).ignore_errors()
# Out:
# Found 23660 files belonging to 2 classes.
# Using 18928 files for training.
# Found 23660 files belonging to 2 classes.
# Using 4732 files for validation.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255),

    tf.keras.layers.Conv2D(32, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(128, (3,3), activation="relu"),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128, activation="relu"),

    tf.keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=1
)
# Out:
#     591/Unknown 769s 1s/step - accuracy: 0.6634 - loss: 0.6068
# C:\Users\kappa\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 826s 1s/step - accuracy: 0.6634 - loss: 0.6068 - val_accuracy: 0.7399 - val_loss: 0.5174

# %%
.ignore_errors()
# Out:
#   Cell In[24], line 1
#     .ignore_errors()
#     ^
# SyntaxError: invalid syntax

# %%
model.save("dogs_vs_cats.keras")

# %%
model.save("dogs_vs_cats.keras")

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=5
)
# Out:
# Epoch 1/5
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 824s 1s/step - accuracy: 0.7789 - loss: 0.4629 - val_accuracy: 0.7921 - val_loss: 0.4412
# Epoch 2/5
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 825s 1s/step - accuracy: 0.8223 - loss: 0.3919 - val_accuracy: 0.8081 - val_loss: 0.4155
# Epoch 3/5
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 823s 1s/step - accuracy: 0.8559 - loss: 0.3302 - val_accuracy: 0.8202 - val_loss: 0.4008
# Epoch 4/5
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 818s 1s/step - accuracy: 0.8908 - loss: 0.2607 - val_accuracy: 0.8039 - val_loss: 0.4650
# Epoch 5/5
# 591/591 ━━━━━━━━━━━━━━━━━━━━ 610s 1s/step - accuracy: 0.9250 - loss: 0.1867 - val_accuracy: 0.8104 - val_loss: 0.5704

# %%
model.save("dogs_vs_cats.keras")

# %%
print("Training Accuracy:", history.history["accuracy"][-1])
print("Validation Accuracy:", history.history["val_accuracy"][-1])
# Out:
# Training Accuracy: 0.9250105619430542
# Validation Accuracy: 0.8104395866394043

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(history.history["accuracy"], marker='o', label="Training Accuracy")
plt.plot(history.history["val_accuracy"], marker='o', label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history["loss"], marker='o', label="Training Loss")
plt.plot(history.history["val_loss"], marker='o', label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training vs Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
print("Training Accuracy:", history.history["accuracy"][-1])
print("Validation Accuracy:", history.history["val_accuracy"][-1])
# Out:
# Training Accuracy: 0.9250105619430542
# Validation Accuracy: 0.8104395866394043

# %%
model.save("dogs_vs_cats.keras")

# %%
import os

print(os.path.exists("dogs_vs_cats.keras"))
# Out:
# True
